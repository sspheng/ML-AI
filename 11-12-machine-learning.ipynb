# %%
import pandas as pd

# %%
data=pd.read_csv('https://raw.githubusercontent.com/codebasics/py/master/ML/9_decision_tree/Exercise/titanic.csv')

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.shape
# Out:
# (891, 12)

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.drop([dt.fit(X_train,y_train)],axis=1,inplace=True)

# %%
data
# Out:
#      Survived  Pclass     Sex   Age            Ticket     Fare
# 0           0       3    male  22.0         A/5 21171   7.2500
# 1           1       1  female  38.0          PC 17599  71.2833
# 2           1       3  female  26.0  STON/O2. 3101282   7.9250
# 3           1       1  female  35.0            113803  53.1000
# 4           0       3    male  35.0            373450   8.0500
# ..        ...     ...     ...   ...               ...      ...
# 886         0       2    male  27.0            211536  13.0000
# 887         1       1  female  19.0            112053  30.0000
# 888         0       3  female   NaN        W./C. 6607  23.4500
# 889         1       1    male  26.0            111369  30.0000
# 890         0       3    male  32.0            370376   7.7500
#
# [891 rows x 6 columns]

# %%
data.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# Ticket        0
# Fare          0
# dtype: int64

# %%
data.Age.fillna(data.Age.mean(),inplace=True)

# %%
data.isna().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# Ticket      0
# Fare        0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
gen=LabelEncoder()
data['Sex']=gen.fit_transform(data['Sex'])

# %%
data
# Out:
#      Survived  Pclass  Sex        Age            Ticket     Fare
# 0           0       3    1  22.000000         A/5 21171   7.2500
# 1           1       1    0  38.000000          PC 17599  71.2833
# 2           1       3    0  26.000000  STON/O2. 3101282   7.9250
# 3           1       1    0  35.000000            113803  53.1000
# 4           0       3    1  35.000000            373450   8.0500
# ..        ...     ...  ...        ...               ...      ...
# 886         0       2    1  27.000000            211536  13.0000
# 887         1       1    0  19.000000            112053  30.0000
# 888         0       3    0  29.699118        W./C. 6607  23.4500
# 889         1       1    1  26.000000            111369  30.0000
# 890         0       3    1  32.000000            370376   7.7500
#
# [891 rows x 6 columns]

# %%
X=data.drop('Survived',axis=1)

# %%
X
# Out:
#      Pclass  Sex        Age            Ticket     Fare
# 0         3    1  22.000000         A/5 21171   7.2500
# 1         1    0  38.000000          PC 17599  71.2833
# 2         3    0  26.000000  STON/O2. 3101282   7.9250
# 3         1    0  35.000000            113803  53.1000
# 4         3    1  35.000000            373450   8.0500
# ..      ...  ...        ...               ...      ...
# 886       2    1  27.000000            211536  13.0000
# 887       1    0  19.000000            112053  30.0000
# 888       3    0  29.699118        W./C. 6607  23.4500
# 889       1    1  26.000000            111369  30.0000
# 890       3    1  32.000000            370376   7.7500
#
# [891 rows x 5 columns]

# %%
y=data.Survived

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test =train_test_split(X,y, train_size=0.70, random_state=0)

# %%
from sklearn import tree

# %%
dt=tree.DecisionTreeClassifier()

# %%
dt.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1940/1065375505.py in <module>
# ----> 1 dt.fit(X_train,y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     901         """
#     902
# --> 903         super().fit(
#     904             X, y,
#     905             sample_weight=sample_weight,
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     155             check_X_params = dict(dtype=DTYPE, accept_sparse="csc")
#     156             check_y_params = dict(ensure_2d=False, dtype=None)
# --> 157             X, y = self._validate_data(X, y,
#     158                                        validate_separately=(check_X_params,
# ...

# %%
X.drop('Ticket',axis=1,inplace=True)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test =train_test_split(X,y, train_size=0.70, random_state=0)

# %%
dt=tree.DecisionTreeClassifier(criterion='entropy',max_depth=5)

# %%
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5)

# %%
dt.score(X_train,y_train)
# Out:
# 0.8459069020866774

# %%
dt.score(X_test,y_test)
# Out:
# 0.8246268656716418

# %%
import matplotlib.pyplot as plt

# %%
fig=plt.figure(figsize=(30,20))
features_names=('Pclass','Age','Sex','Fare')
tree.plot_tree(dt,feature_names=features_names,class_names='Survived',filled=True)
plt.show()
